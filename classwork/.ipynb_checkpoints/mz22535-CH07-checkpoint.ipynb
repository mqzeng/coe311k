# %%
import numpy as np
import time

def jacobi(A, b, x0, tol, maxIter):
    n = len(b)
    x = x0.copy()
    
    for k in range(maxIter):
        xnew = np.zeros_like(x)
        
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            xnew[i] = (b[i] - s) / A[i][i]
        
        if np.linalg.norm(xnew - x, ord=np.inf) < tol:
            return xnew, k
        
        x = xnew
        
    return x, maxIter

def gs(A, b, x0, tol, maxIter):
    n = len(b)
    x = x0.copy()
    
    for k in range(maxIter):
        xnew = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * xnew[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
            xnew[i] = (b[i] - s1 - s2) / A[i][i]
            
        if np.linalg.norm(xnew - x, ord=np.inf) < tol:
            return xnew, k
        
        x = xnew
        
    return x, maxIter

A = np.array([

[0.582745, 0.48 , 0.10 , 0.  , 0.  ],
[0.48 , 1.044129, 0.46 , 0.10 , 0.  ],
[0.10 , 0.46 , 1.10431 , 0.44 , 0.10 ],
[0.  , 0.10 , 0.44 , 0.963889, 0.42 ],
[0.  , 0.  , 0.10 , 0.42 , 0.522565]], dtype=float)

b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)
             
x0 = np.zeros_like(b)
tol = 1e-6
maxIter = 1000

start = time.time()
jacSol, jacIter = jacobi(A, b, x0, tol, maxIter)
jacTime = time.time() - start

start = time.time()
gsSol, gsIter = gs(A, b, x0, tol, maxIter)
gsTime = time.time() - start

print("jacobi matrix: ", jacSol, "iterations:", jacIter, " time:", jacTime)
print("gs matrix:     ", gsSol, "iterations:", gsIter, " time:", gsTime)
# Out:
# jacobi matrix:  [0.9848677  0.98485984 0.98485878 0.98486297 0.98487321] iterations: 1000  time: 0.04160332679748535
# gs matrix:      [0.99999926 1.00000045 0.99999989 0.99999997 1.00000005] iterations: 20  time: 0.0009591579437255859

# %%
A = np.array([[1, 1], [1, 1.0001]])
b = np.array([1, 1])

x0 = np.zeros_like(b)
tol = 1e-6
maxIter = 1000

start = time.time()
jacSol, jacIter = jacobi(A, b, x0, tol, maxIter)
jacTime = time.time() - start

start = time.time()
gsSol, gsIter = gs(A, b, x0, tol, maxIter)
gsTime = time.time() - start

print("jacobi matrix: ", jacSol, "iterations:", jacIter, " time:", jacTime)
print("gs matrix:     ", gsSol, "iterations:", gsIter, " time:", gsTime)
# Out:
# jacobi matrix:  [1 0] iterations: 1  time: 0.0004544258117675781
# gs matrix:      [1 0] iterations: 1  time: 0.0002818107604980469

# %%
A = np.array([[1, 1], [1, 1.0001]])
b = np.array([1, 1.0001])

x0 = np.zeros_like(b)
tol = 1e-6
maxIter = 1000

start = time.time()
jacSol, jacIter = jacobi(A, b, x0, tol, maxIter)
jacTime = time.time() - start

start = time.time()
gsSol, gsIter = gs(A, b, x0, tol, maxIter)
gsTime = time.time() - start

print("jacobi matrix: ", jacSol, "iterations:", jacIter, " time:", jacTime)
print("gs matrix:     ", gsSol, "iterations:", gsIter, " time:", gsTime)
# Out:
# jacobi matrix:  [0.        0.0487682] iterations: 1000  time: 0.03439927101135254
# gs matrix:      [0.90493243 0.09515806] iterations: 1000  time: 0.021658658981323242
