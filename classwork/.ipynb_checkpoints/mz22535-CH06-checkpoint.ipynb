# %%
import numpy as np
import time

def jacobi(A, b, x0, tol, maxIter):
    n = len(b)
    x = x0.copy()
    
    for k in range(maxIter):
        xnew = np.zeros_like(x)
        
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            xnew[i] = (b[i] - s) / A[i][i]
        
        if np.linalg.norm(xnew - x, ord=np.inf) < tol:
            return xnew, k
        
        x = xnew
        
    return x, maxIter

def gs(A, b, x0, tol, maxIter):
    n = len(b)
    x = x0.copy()
    
    for k in range(maxIter):
        xnew = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * xnew[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
            xnew[i] = (b[i] - s1 - s2) / A[i][i]
            
        if np.linalg.norm(xnew - x, ord=np.inf) < tol:
            return xnew, k
        
        x = xnew
        
    return x, maxIter

A = np.array([
    [10, -1, 2, 0, 0],
    [-1, 11, -1, 3, 0],
    [2, -1, 10, -1, 0],
    [0, 3, -1, 8, -2],
    [0, 0, 0, -2, 9]
], dtype=float)

b = np.array([14, 30, 26, 25, 37], dtype=float)

x0 = np.zeros_like(b)
tol = 1e-6
maxIter = 1000

start = time.time()
jacSol, jacIter = jacobi(A, b, x0, tol, maxIter)
jacTime = time.time() - start

start = time.time()
gsSol, gsIter = gs(A, b, x0, tol, maxIter)
gsTime = time.time() - start

print("jacobi matrix: ", jacSol, "iterations:", jacIter, " time:", jacTime)
print("gs matrix:     ", gsSol, "iterations:", gsIter, " time:", gsTime)
# Out:
# jacobi matrix:  [0.99999995 2.00000025 2.99999986 4.00000008 4.99999983] iterations: 18  time: 0.0010733604431152344
# gs matrix:      [1.00000003 2.00000002 2.99999999 3.99999998 5.        ] iterations: 10  time: 0.0005805492401123047

# %%
A = np.array([
    [1, 2, 3, 0, 0],
    [2, 1, 2, 3, 0],
    [3, 2, 1, 2, 3],
    [0, 3, 2, 1, 2],
    [0, 0, 3, 2, 1]
], dtype=float)

b = np.array([14, 22, 33, 26, 22], dtype=float)

x0 = np.zeros_like(b)
tol = 1e-6
maxIter = 1000

start = time.time()
jacSol, jacIter = jacobi(A, b, x0, tol, maxIter)
jacTime = time.time() - start

start = time.time()
gsSol, gsIter = gs(A, b, x0, tol, maxIter)
gsTime = time.time() - start

print("jacobi matrix: ", jacSol, "iterations:", jacIter, " time:", jacTime)
print("gs matrix:     ", gsSol, "iterations:", gsIter, " time:", gsTime)
# ^ Solving Ax = b doesn't converge to a single solution --> keeps iterating and solution fails
# Out:
# jacobi matrix:  [nan nan nan nan nan] iterations: 1000  time: 0.05772686004638672
# gs matrix:      [nan nan nan nan nan] iterations: 1000  time: 0.050414085388183594
# <ipython-input-1-8ffe1ca8ad4c>:12: RuntimeWarning: overflow encountered in double_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# <ipython-input-1-8ffe1ca8ad4c>:12: RuntimeWarning: invalid value encountered in double_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# <ipython-input-1-8ffe1ca8ad4c>:30: RuntimeWarning: overflow encountered in double_scalars
#   s1 = sum(A[i][j] * xnew[j] for j in range(i))
# <ipython-input-1-8ffe1ca8ad4c>:31: RuntimeWarning: overflow encountered in double_scalars
#   s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
# <ipython-input-1-8ffe1ca8ad4c>:31: RuntimeWarning: invalid value encountered in double_scalars
#   s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
