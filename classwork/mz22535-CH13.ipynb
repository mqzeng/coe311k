# %%
import numpy as np
import time
import matplotlib.pyplot as plt

def naive_matmul(A, B):
    rows_A, cols_A = len(A), len(A[0])
    cols_B = len(B[0])
    C = [[0] * cols_B for _ in range(rows_A)]
    for i in range(rows_A):
        for j in range(cols_B):
            for k in range(cols_A):
                C[i][j] += A[i][k] * B[k][j]
    return C

sizes = [3 * (2 ** i) for i in range(8)]
naive_times = []
numpy_times = []

for size in sizes:
    A = np.random.rand(size, size)
    B = np.random.rand(size, size)

    A_list = A.tolist()
    B_list = B.tolist()
    start = time.time()
    naive_matmul(A_list, B_list)
    naive_times.append(time.time() - start)
    
    start = time.time()
    np.dot(A, B)
    numpy_times.append(time.time() - start)

    print(f"Size {size:4d}x{size:<4d} | Naive: {naive_times[-1]:.4f}s | NumPy: {numpy_times[-1]:.6f}s")

# Plot
plt.figure(figsize=(10, 5))
plt.plot(range(1, 9), naive_times, 'r-o'
# Out:
#   File "<ipython-input-1-77537d6c8fe9>", line 36
#     plt.plot(range(1, 9), naive_times, 'r-o'
#                                             ^
# SyntaxError: unexpected EOF while parsing
